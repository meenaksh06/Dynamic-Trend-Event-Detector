# %% [markdown]
# # Phase 2: Temporal Forecasting using LSTM
#
# This notebook focuses on forecasting the evolution of topic proportions over time using a **Long Short-Term Memory (LSTM)** network. We use the topic distributions discovered by BERTopic and aggregate them monthly to create a multivariate time series.
#
# ### Goals:
# 1. Aggregate topic proportions per month.
# 2. Train a multivariate LSTM to forecast future topic probabilities.
# 3. Visualize projected trend evolution.

# %%
# ==========================================
# 📦 1. Imports
# ==========================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2


# ==========================================
# 📂 2. Load Data
# ==========================================
df = pd.read_csv('/content/processed_featured_data.csv')

df['date'] = pd.to_datetime(df['date'])
df['year_month'] = df['date'].dt.to_period('M')
df['year_month_str'] = df['year_month'].astype(str)

print("✅ Data loaded:", df.shape)


# ==========================================
# 🧠 3. CREATE dominant_topic (LDA FIX)
# ==========================================
print("Running quick LDA...")

vectorizer = CountVectorizer(max_features=5000, stop_words='english')
X = vectorizer.fit_transform(df['clean_text'].fillna(""))

lda = LatentDirichletAllocation(n_components=10, random_state=42)
lda.fit(X)

topic_dist = lda.transform(X)
df['dominant_topic'] = topic_dist.argmax(axis=1)

print("✅ dominant_topic created")


# ==========================================
# 📊 4. Create Topic Time-Series
# ==========================================
topic_trends = df.groupby(
    ['year_month_str', 'dominant_topic']
).size().unstack().fillna(0)

topic_trends = topic_trends.sort_index()


# ==========================================
# ✂️ 5. Train-Test Split (FIXED)
# ==========================================
window_size = 5
train_size = int(len(topic_trends) * 0.8)

train = topic_trends.iloc[:train_size]
test = topic_trends.iloc[train_size - window_size:]


# ==========================================
# ⚖️ 6. Scaling
# ==========================================
scaler = MinMaxScaler()

train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)


# ==========================================
# 🔁 7. Sequence Creation
# ==========================================
def create_sequences(data, window=5):
    X, y = [], []
    for i in range(len(data)-window):
        X.append(data[i:i+window])
        y.append(data[i+window])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_scaled, window_size)
X_test, y_test = create_sequences(test_scaled, window_size)


# ==========================================
# 🧠 8. LSTM Model (BiLSTM + Regularization)
# ==========================================

model = Sequential([
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(32)),
    Dropout(0.3),
    Dense(X_train.shape[2], kernel_regularizer=l2(0.001))
])

# 🔥 FIX: Added compile call
model.compile(optimizer='adam', loss='mse')


# ==========================================
# 🛑 9. Training
# ==========================================
early_stop = EarlyStopping(patience=5, restore_best_weights=True)

model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=16,
    validation_data=(X_test, y_test),
    callbacks=[early_stop],
    verbose=1
)


# ==========================================
# 🔮 10. Prediction + Inverse Transform
# ==========================================
pred_scaled = model.predict(X_test)
baseline_scaled = X_test[:, -1, :]

pred = scaler.inverse_transform(pred_scaled)
baseline = scaler.inverse_transform(baseline_scaled)
y_test_unscaled = scaler.inverse_transform(y_test)


# ==========================================
# 📊 11. Evaluation
# ==========================================
lstm_mse = mean_squared_error(
    y_test_unscaled.flatten(),
    pred.flatten()
)

baseline_mse = mean_squared_error(
    y_test_unscaled.flatten(),
    baseline.flatten()
)

print(f"\nLSTM MSE: {lstm_mse:.2f}")
print(f"Baseline MSE: {baseline_mse:.2f}")


# ==========================================
# 📈 12. Visualization
# ==========================================
topic_index = 0

plt.figure(figsize=(10,5))
plt.plot(y_test_unscaled[:, topic_index], label="Actual")
plt.plot(pred[:, topic_index], label="LSTM")
plt.plot(baseline[:, topic_index], label="Baseline", linestyle='--')

plt.title("Topic Forecasting (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Topic Count")
plt.legend()
plt.show()
# Out:
# ✅ Data loaded: (10000, 19)
# Running quick LDA...
# ✅ dominant_topic created
# Epoch 1/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 553ms/step - loss: 0.0303 - val_loss: 0.0261
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0254 - val_loss: 0.0228
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0226 - val_loss: 0.0210
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0207 - val_loss: 0.0202
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0199 - val_loss: 0.0196
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0200 - val_loss: 0.0188
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0194 - val_loss: 0.0180
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0186 - val_loss: 0.0174
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0181 - val_loss: 0.0170
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0176 - val_loss: 0.0167
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0171 - val_loss: 0.0166
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0166 - val_loss: 0.0164
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0162 - val_loss: 0.0161
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0158 - val_loss: 0.0158
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0153 - val_loss: 0.0148
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0149 - val_loss: 0.0143
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0145 - val_loss: 0.0139
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0142 - val_loss: 0.0136
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0139 - val_loss: 0.0134
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0133 - val_loss: 0.0132
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0135 - val_loss: 0.0130
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0128 - val_loss: 0.0127
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0125 - val_loss: 0.0124
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0122 - val_loss: 0.0122
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0120 - val_loss: 0.0120
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0119 - val_loss: 0.0116
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0109 - val_loss: 0.0109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
#
# LSTM MSE: 55.84
# Baseline MSE: 63.50
